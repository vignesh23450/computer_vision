# %% [markdown]
# OpenCV (Open Source Computer Vision) is an open-source library of computer vision and machine learning algorithms. It provides a wide range of tools and functions that enable developers to create applications for various tasks related to image and video processing, object detection and tracking, facial recognition, and more

# %% [markdown]
# 1 Imread
# 2 Imshow
# 3 WaitKey
# 4 DestroyAllWindows
# 5 CvtColor
# 6 GaussianBlur
# 7 Blur
# 8 Canny
# 9 Dilate
# 10 VideoCapture
# 11 isOpened
# 12 rectangle
# 13 circle
# 14 line
# 15 putText
# 16 imwrite

# %%
import cv2 as c
print(c.__version__)
# Out:
# 4.7.0

# %%
im=c.imread('jocker-comic-ai-artwork-901.webp')
c.imshow('op',im)
c.waitKey(0)
c.destroyAllWindows()
print(im)
# Out:
# [[[ 36 145 235]
#   [ 36 145 235]
#   [ 36 145 235]
#   ...
#   [107 126  16]
#   [107 126  16]
#   [107 126  16]]
#
#  [[ 36 145 235]
#   [ 36 145 235]
#   [ 36 145 235]
#   ...
#   [107 126  16]
#   [107 126  16]
#   [107 126  16]]
#
#  [[ 38 146 236]
#   [ 38 146 236]
#   [ 38 146 236]
#   ...
#   [107 126  16]
#   [107 126  16]
#   [107 126  16]]
#
#  ...
#
#  [[ 32   0   0]
#   [ 32   0   0]
#   [ 32   0   0]
#   ...
#   [183  82 158]
#   [183  82 158]
#   [191  91 166]]
#
#  [[ 32   0   0]
#   [ 32   0   0]
#   [ 32   0   0]
#   ...
#   [193  93 168]
#   [193  93 168]
#   [202 101 177]]
#
#  [[ 32   0   0]
#   [ 32   0   0]
#   [ 32   0   0]
#   ...
#   [186  86 161]
#   [186  86 161]
#   [195  94 170]]]

# %%
# Converting to grayscale
import cv2 as cv
img = cv.imread('jocker-comic-ai-artwork-901.webp')
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv.imshow('Gray', gray)
cv.waitKey(0)
# Out:
# -1

# %%
#Image Blurring:

import cv2

# Load an image
image = cv2.imread('jocker-comic-ai-artwork-901.webp')

# Apply Gaussian blur
blurred_image = cv2.GaussianBlur(image, (5,5), 0)

# Display the blurred image
cv2.imshow('Blurred Image', blurred_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Image Blurring:

import cv2

# Load an image
image = cv2.imread('jocker-comic-ai-artwork-901.webp')

# Apply Gaussian blur
blurred_image = cv2.blur(image, (5, 5))

# Display the blurred image
cv2.imshow('Blurred Image', blurred_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Image Taking edges:
import cv2

# Load an image
image = cv2.imread('jocker-comic-ai-artwork-901.webp')

image = cv2.Canny(image, 125, 175)

cv2.imshow('Image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Image Taking dilate:
import cv2

# Load an image
image = cv2.imread('jocker-comic-ai-artwork-901.webp')

image = cv2.dilate(image, (125, 175),iterations=10)

cv2.imshow('Image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Image Taking erode:
import cv2

# Load an image
image = cv2.imread('jocker-comic-ai-artwork-901.webp')

image = cv2.erode(image, (125, 175),iterations=10)

cv2.imshow('Image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Resizing

# %%
#Image resize:
import cv2

# Load an image
image = cv2.imread('jocker-comic-ai-artwork-901.webp')

image = cv2.resize(image, (125, 175),interpolation=cv2.INTER_CUBIC)

cv2.imshow('Image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Image croping:
import cv2

# Load an image
image = cv2.imread('jocker-comic-ai-artwork-901.webp')

image = image[0:500,0:250]

cv2.imshow('Image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
a=100
b='D'
c='10'
print(a)
print(chr(a))
print(ord(b))
# Out:
# 100
# d
# 68

# %%
#videos
import cv2
import sys
capture = cv2.VideoCapture('E:\\pexels-cottonbro-studio-5532773-4096x2160-25fps.mp4')
while True:
    isTrue, frame = capture.read()
    cv2.imshow('videos',frame)
    if cv2.waitKey(20) & 0xFF == ord('q'):
        break
capture.release()
cv2.destroyAllWindows

# %%
#Capturing Video from a Webcam:

import cv2

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    # Check if the frame is empty or has invalid dimensions
    if not ret or frame.size == 0:
        continue

    cv2.imshow('Video', frame)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
# Create a VideoCapture object and read from input file
# If the input is the camera, pass 0 instead of the video file name
cap = cv2.VideoCapture('E:\\pexels-cottonbro-studio-5532773-4096x2160-25fps.mp4')
# Check if camera opened successfully
if (cap.isOpened()== False):
    print("Error opening video stream or file")
    # Read until video is completed
while(cap.isOpened()):
    # Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True:
        # Display the resulting frame
        cv2.imshow('Frame',frame)
        # Press Q on keyboard to  exit
        if cv2.waitKey(3000) & 0xFF == ord('q'):
            break# Break the loop
        else:
            break# When everything done, release the video capture object
cap.release()
# Closes all the frames
cv2.destroyAllWindows()

# %%
import cv2

fw=640
fh=360

cap = cv2.VideoCapture('E:\\pexels-cottonbro-studio-5532773-4096x2160-25fps.mp4')

while True:
    ret,img=cap.read()
    cv2.imshow("video",img)
    
     # Check if the frame is empty or has invalid dimensions
    if not ret or img.size == 0:
        continue

    cv2.imshow('Video', img)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2

fw=640
fh=360

cap = cv2.VideoCapture('E:\\pexels-cottonbro-studio-5532773-4096x2160-25fps.mp4')
cap.set(3,fw)
cap.set(4,fh)
while True:
    ret,img=cap.read()
    cv2.imshow("video",img)
    img = cv2.resize(img, (125, 175),interpolation=cv2.INTER_CUBIC)
     # Check if the frame is empty or has invalid dimensions
    if not ret or img.size == 0:
        continue

    cv2.imshow('Video', img)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2

fw=640
fh=360

cap = cv2.VideoCapture('E:\\pexels-cottonbro-studio-5532773-4096x2160-25fps.mp4')

while True:
    ret,img=cap.read()
    cv2.imshow("video",img)
    
    img = cv2.Canny(img, 125, 175)
     # Check if the frame is empty or has invalid dimensions
    if not ret or img.size == 0:
        continue

    cv2.imshow('Video', img)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2

fw=640
fh=480

cap = cv2.VideoCapture('E:\\pexels-cottonbro-studio-5532773-4096x2160-25fps.mp4')
cap.set(3,fw)
cap.set(4,fh)
while True:
    ret,img=cap.read()
    cv2.imshow("video",img)
    
    img = cv2.erode(img, (125, 175),iterations=10)
     # Check if the frame is empty or has invalid dimensions
    if not ret or img.size == 0:
        continue

    cv2.imshow('Video', img)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2

fw=640
fh=480

cap = cv2.VideoCapture('E:\\pexels-cottonbro-studio-5532773-4096x2160-25fps.mp4')
cap.set(3,fw)
cap.set(4,fh)
while True:
    ret,img=cap.read()
    cv2.imshow("video",img)
    
    img = cv2.erode(img, (125, 175),iterations=10)
     # Check if the frame is empty or has invalid dimensions
    if not ret or img.size == 0:
        continue

    cv2.imshow('Video', img)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Day2

# %% [markdown]
# # drawing the shapes

# %%
import cv2 as cv
import numpy as np

 

blank = np.zeros((500,500,3), dtype='uint8')
cv.imshow('Blank', blank)
cv.waitKey(0)
# Out:
# -1

# %%
# 1. Paint the image a certain colour
blank[200:300, 300:400] = 299, 235, 3
cv.imshow('Green', blank)
cv.waitKey(0)
# Out:
# -1

# %%
# 2. Draw a Rectangle
cv.rectangle(blank, (0,0), (blank.shape[1]//2, blank.shape[0]//2), (0,255,0), thickness=-1)
cv.imshow('Rectangle', blank)
cv.waitKey(0)
# Out:
# -1

# %%
# 3. Draw A circle
cv.circle(blank, (blank.shape[1]//2, blank.shape[0]//2), 40, (0,0,255), thickness=-1)
cv.imshow('Circle', blank)
cv.waitKey(0)
# Out:
# -1

# %%
# 4. Draw a line
cv.line(blank, (100,250), (300,400), (255,255,255), thickness=3)
cv.imshow('Line', blank)
cv.waitKey(0)
# Out:
# -1

# %%
# 5. Write text
cv.putText(blank, 'Welcome to RACE!!!', (100,225), cv.FONT_HERSHEY_TRIPLEX, 1.0, (255,255,255), 3)
cv.imshow('Text', blank)
cv.waitKey(0)
# Out:
# -1

# %% [markdown]
# # How to Read, Write, Show Videos from Camera in OpenCV

# %%
#webcam access
import cv2
cap = cv2.VideoCapture(0);

 

while(True):
    ret, frame = cap.read()
    cv2.imshow('frame',frame)

    if cv2.waitKey(1) & 0xFF == ord('p'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
#webcam access with gray scale
import cv2
cap = cv2.VideoCapture(0);

 

while(True):
    ret, frame = cap.read()
    gray = cv2.cvtColor( frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow('frame',gray)

    if cv2.waitKey(1) & 0xFF == ord('p'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import cv2 as cv
import sys
img = cv.imread(cv.samples.findFile("photo"))
if img is None:
    sys.exit("Could not read the image.")
cv.imshow("Display window", img)
k = cv.waitKey(0)
if k == ord("s"):
    cv.imwrite("starry_night1.png", img)
cv.destroyAllWindows()

# %%
fourcc = cv2.VideoWriter_fourcc(*'h264')
#or 
#fourcc = cv2.VideoWriter_fourcc(*'x264')
#or
#fourcc = cv2.VideoWriter_fourcc(*'mp4v')

# %%
import cv2
cap = cv2.VideoCapture(0)
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output1.mp4',fourcc,20.0,(640,480))
print(cap.isOpened())

 


while(cap.isOpened()):
    ret, frame = cap.read()
    if ret == True:
        print(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        print(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        print(cap.get(cv2.CAP_PROP_FRAME_COUNT))

        out.write(frame)

        #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        cv2.imshow('frame',frame)

        if cv2.waitKey(1) & 0xFF == ord('p'):
            break
    else:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# True
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# 640.0
# 480.0
# -1.0
# ...

# %%
import cv2
cap = cv2.VideoCapture(0)
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.mp4',fourcc,20.0,(640,480))

 

print(cap.isOpened())
# Out:
# True

# %%
im=cv2.imread('Basic-diagram-of-self-driving-car.png')
im=cv2.line(im, (0,5), (30,60), (255,0,255), thickness=5)
cv2.imshow('op',im)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
im=cv2.imread('Basic-diagram-of-self-driving-car.png')
im=cv2.arrowedLine(im, (0,5), (40,80), (255,0,255), thickness=5)
cv2.imshow('op',im)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
im=cv2.imread('Basic-diagram-of-self-driving-car.png')
im=cv2.rectangle(im,  (50,50), (400,300), (255,0,255), 3)
cv2.imshow('op',im)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
im=cv2.imread('Basic-diagram-of-self-driving-car.png')
im=cv2.rectangle(im, (0,0), (im.shape[1]//2, im.shape[0]//2), (0,255,0), thickness=-1)
cv2.imshow('op',im)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
im=cv2.imread('Basic-diagram-of-self-driving-car.png')
im=cv2.circle(im, (im.shape[1]//2, im.shape[0]//2), 40, (0,0,255), thickness=-1)
cv2.imshow('op',im)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
im=cv2.imread('Basic-diagram-of-self-driving-car.png')
im=cv2.circle(im, (im.shape[1]//2, im.shape[0]//2), 40, (0,0,255), thickness=3)
cv2.imshow('op',im)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2 as cv
im=cv.imread('Basic-diagram-of-self-driving-car.png')
im=cv.putText(im, 'my future', (100,225), cv.FONT_HERSHEY_TRIPLEX, 1.0, (205,230,5), 3)
cv.imshow('op',im)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import cv2 as cv
im=cv.imread('Basic-diagram-of-self-driving-car.png')
im=cv.putText(im, 'my future!!', (100,225), cv.FONT_HERSHEY_TRIPLEX, 1.0, (205,230,5), 3,cv.LINE_AA)
cv.imshow('op',im)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import cv2 as cv
im=cv.imread('Basic-diagram-of-self-driving-car.png')
im=cv.putText(im, 'my future!!', (100,225), cv.FONT_HERSHEY_TRIPLEX, 1.0, (205,230,5), 3,cv.LINE_4)
cv.imshow('op',im)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import cv2 as cv
im=cv.imread('Basic-diagram-of-self-driving-car.png')
im=cv.putText(im, 'my future!!', (100,225), cv.FONT_HERSHEY_TRIPLEX, 1.0, (205,230,5), 3,cv.LINE_8)
cv.imshow('op',im)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv

 

events = [i for i in dir(cv) if 'FONT' in i]
print(events)
# Out:
# ['FONT_HERSHEY_COMPLEX', 'FONT_HERSHEY_COMPLEX_SMALL', 'FONT_HERSHEY_DUPLEX', 'FONT_HERSHEY_PLAIN', 'FONT_HERSHEY_SCRIPT_COMPLEX', 'FONT_HERSHEY_SCRIPT_SIMPLEX', 'FONT_HERSHEY_SIMPLEX', 'FONT_HERSHEY_TRIPLEX', 'FONT_ITALIC', 'QT_FONT_BLACK', 'QT_FONT_BOLD', 'QT_FONT_DEMIBOLD', 'QT_FONT_LIGHT', 'QT_FONT_NORMAL']

# %%
import numpy as np
import cv2 as cv

 

events = [i for i in dir(cv) if 'EVENT' in i]
print(events)
# Out:
# ['EVENT_FLAG_ALTKEY', 'EVENT_FLAG_CTRLKEY', 'EVENT_FLAG_LBUTTON', 'EVENT_FLAG_MBUTTON', 'EVENT_FLAG_RBUTTON', 'EVENT_FLAG_SHIFTKEY', 'EVENT_LBUTTONDBLCLK', 'EVENT_LBUTTONDOWN', 'EVENT_LBUTTONUP', 'EVENT_MBUTTONDBLCLK', 'EVENT_MBUTTONDOWN', 'EVENT_MBUTTONUP', 'EVENT_MOUSEHWHEEL', 'EVENT_MOUSEMOVE', 'EVENT_MOUSEWHEEL', 'EVENT_RBUTTONDBLCLK', 'EVENT_RBUTTONDOWN', 'EVENT_RBUTTONUP']

# %%
def click_event(event,x,y,flags,param):
    if event == cv.EVENT_LBUTTONDOWN:
        print(x,', ',y)
        font = cv.FONT_HERSHEY_SIMPLEX
        strxy = str(x) + ', '+ str(y)
        cv.putText(img,strxy,(x,y),font,1,(255,255,0),2)
        cv.imshow('image',img)
img = np.zeros((512,512,3),np.uint8)
cv.imshow('image',img)

 

cv.setMouseCallback('image',click_event)

 

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 244 ,  140
# 322 ,  248

# %%
def click_event(event,x,y,flags,param):
    if event == (cv.EVENT_LBUTTONDOWN) or (cv.EVENT_RBUTTONDOWN):
        print(x,', ',y)
        font = cv.FONT_HERSHEY_SIMPLEX
        strxy = str(x) + ', '+ str(y)
        cv.putText(img,strxy,(x,y),font,1,(255,255,0),2)
        cv.imshow('image',img)
img = np.zeros((512,512,3),np.uint8)
cv.imshow('image',img)

 

cv.setMouseCallback('image',click_event)

 

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 287 ,  137
# 287 ,  137
# 287 ,  137
# 287 ,  137
# 287 ,  137
# 287 ,  137
# 287 ,  137
# 286 ,  143
# 285 ,  151
# 282 ,  156
# 278 ,  162
# 277 ,  168
# 275 ,  171
# 274 ,  177
# 271 ,  180
# 269 ,  185
# 268 ,  187
# 267 ,  189
# 266 ,  192
# 266 ,  195
# 265 ,  196
# 265 ,  197
# 264 ,  199
# 264 ,  200
# 264 ,  201
# 264 ,  202
# 264 ,  203
# 264 ,  203
# 264 ,  204
# 264 ,  205
# 270 ,  205
# 280 ,  204
# 289 ,  204
# 298 ,  204
# 306 ,  204
# 314 ,  205
# 322 ,  207
# 330 ,  208
# 338 ,  211
# 344 ,  211
# 350 ,  213
# 353 ,  216
# 356 ,  218
# 358 ,  219
# 361 ,  221
# 363 ,  223
# 365 ,  224
# 366 ,  226
# 366 ,  227
# 367 ,  228
# 368 ,  231
# 370 ,  232
# 370 ,  234
# 370 ,  235
# 370 ,  237
# 370 ,  238
# 370 ,  239
# 370 ,  240
# 370 ,  241
# 370 ,  242
# 370 ,  243
# 370 ,  245
# 369 ,  247
# 368 ,  247
# 367 ,  250
# 366 ,  251
# 366 ,  253
# 364 ,  254
# 361 ,  258
# 358 ,  260
# 354 ,  263
# 349 ,  268
# 341 ,  273
# 331 ,  279
# 322 ,  285
# 310 ,  291
# ...

# %%
def click_event(event,x,y,flags,param):
    if event == (cv.EVENT_LBUTTONDBLCLK) or (cv.EVENT_RBUTTONDBLCLK):
        print(x,', ',y)
        font = cv.FONT_HERSHEY_SIMPLEX
        strxy = str(x) + ', '+ str(y)
        cv.putText(img,strxy,(x,y),font,1,(255,255,0),2)
        cv.imshow('image',img)
img = np.zeros((512,512,3),np.uint8)
cv.imshow('image',img)

 

cv.setMouseCallback('image',click_event)

 

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 303 ,  130
# 303 ,  130
# 302 ,  133
# 301 ,  140
# 300 ,  147
# 299 ,  153
# 298 ,  159
# 298 ,  167
# 296 ,  172
# 295 ,  179
# 294 ,  186
# 292 ,  193
# 291 ,  201
# 290 ,  208
# 290 ,  214
# 287 ,  219
# 286 ,  223
# 286 ,  229
# 285 ,  232
# 283 ,  237
# 282 ,  239
# 282 ,  242
# 281 ,  244
# 280 ,  246
# 280 ,  247
# 280 ,  247
# 280 ,  248
# 279 ,  249
# 279 ,  250
# 279 ,  251
# 279 ,  251
# 279 ,  252
# 279 ,  253
# 279 ,  254
# 279 ,  254
# 279 ,  254
# 279 ,  254
# 288 ,  256
# 299 ,  259
# 311 ,  265
# 323 ,  269
# 333 ,  272
# 343 ,  275
# 350 ,  277
# 357 ,  279
# 362 ,  281
# 367 ,  283
# 370 ,  286
# 374 ,  286
# 376 ,  287
# 378 ,  287
# 379 ,  289
# 380 ,  290
# 381 ,  291
# 382 ,  291
# 382 ,  292
# 382 ,  293
# 382 ,  294
# 382 ,  295
# 382 ,  295
# 382 ,  296
# 382 ,  297
# 382 ,  298
# 382 ,  299
# 382 ,  299
# 382 ,  300
# 382 ,  301
# 382 ,  302
# 382 ,  303
# 382 ,  304
# 382 ,  305
# 380 ,  305
# 377 ,  307
# 374 ,  308
# 366 ,  313
# 357 ,  317
# ...

# %%
import cv2 as cv
def click_event(event,x,y,flags,param):
    if event == (cv.EVENT_LBUTTONDOWN):
        print(x,', ',y)
        font = cv.FONT_HERSHEY_SIMPLEX
        strxy = str(x) + ', '+ str(y)
        cv.putText(img,strxy,(x,y),font,1,(255,255,0),2)
        cv.imshow('image',img)
img = cv.imread('Basic-diagram-of-self-driving-car.png')
cv.imshow('image',img)

 

cv.setMouseCallback('image',click_event)

 

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 442 ,  131
# 282 ,  158

# %% [markdown]
# # Home

# %%
import cv2 as cv

cap = cv.VideoCapture(0)

while True:
    ret, frame = cap.read()

    # Check if the frame is empty or has invalid dimensions
    if not ret or frame.size == 0:
        continue
    frame=cv.circle(frame, (frame.shape[1]//2, frame.shape[0]//2), 40, (0,0,255), thickness=3)
    cv.imshow('Video', frame)

    if cv.waitKey(1) == ord('q'):
        break

cap.release()
cv.destroyAllWindows()

# %%
import cv2 as cv

def click_event(event,x,y,flags,param):
    if event == (cv.EVENT_LBUTTONDOWN):
        print(x,', ',y)
        font = cv.FONT_HERSHEY_SIMPLEX
        strxy = str(x) + ', '+ str(y)
        cv.putText(img,strxy,(x,y),font,1,(255,255,0),2)
        cv.imshow('image',img)

cap = cv.VideoCapture(0)

while True:
    ret, frame = cap.read()

    # Check if the frame is empty or has invalid dimensions
    if not ret or frame.size == 0:
        continue
    frame=cv.setMouseCallback('image',click_event)
    cv.imshow('Video', frame)

    if cv.waitKey(1) == ord('q'):
        break

cap.release()
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 19
#      17 if not ret or frame.size == 0:
#      18     continue
# ---> 19 frame=cv.setMouseCallback('image',click_event)
#      20 cv.imshow('Video', frame)
#      22 if cv.waitKey(1) == ord('q'):
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:2558: error: (-27:Null pointer) NULL window: 'image' in function 'cvSetMouseCallback'

# %%
import cv2 as cv

cap = cv.VideoCapture(0)

while True:
    ret, frame = cap.read()

    # Check if the frame is empty or has invalid dimensions
    if not ret or frame.size == 0:
        continue
    frame=cv.line( frame, ((frame.shape[1]//2)-100,0), ((frame.shape[1]//2)-100,600), (255,0,255), thickness=5)
    frame=cv.line( frame, ((frame.shape[1]//2)+100,0), ((frame.shape[1]//2)+100,600), (255,0,255), thickness=5)
    cv.imshow('Video', frame)

    if cv.waitKey(1) == ord('q'):
        break

cap.release()
cv.destroyAllWindows()

# %%
import cv2 as cv

cap = cv.VideoCapture(0)

while True:
    ret, frame = cap.read()

    # Check if the frame is empty or has invalid dimensions
    if not ret or frame.size == 0:
        continue
    frame=cv.circle(frame, (frame.shape[1]//2, frame.shape[0]//2), 100, (0,0,255), thickness=3)    
    frame=cv.line( frame, ((frame.shape[1]//2)-100,0), ((frame.shape[1]//2)-100,600), (255,0,255), thickness=5)
    frame=cv.line( frame, (0,(frame.shape[1]//2)-300), (1800,(frame.shape[1]//2)-300), (255,0,255), thickness=5)
    frame=cv.line( frame, ((frame.shape[1]//2)+100,0), ((frame.shape[1]//2)+100,600), (255,0,255), thickness=5)
    frame=cv.line( frame, (0,(frame.shape[1]//2)+100), (1800,(frame.shape[1]//2)+100), (255,0,255), thickness=5)
    cv.imshow('Video', frame)

    if cv.waitKey(1) == ord('q'):
        break

cap.release()
cv.destroyAllWindows()

# %% [markdown]
# # Day 3

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline 
    
img = cv.imread('jocker-comic-ai-artwork-901.webp')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.imshow('Gray', img)
cv.waitKey(0)
cv.destroyAllWindows()

plt.imshow(img)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

 

# %matplotlib inline

 

img = cv2.imread('jocker-comic-ai-artwork-901.webp', 1)
# img = cv2.resize(img, (500,500))
print(img.shape)
cv2.imshow('Mycar', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

 

#============plot===========
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
# Out:
# (1024, 1024, 3)

# %%
img = cv2.imread('jocker-comic-ai-artwork-901.webp', 1)
img2 = cv2.imread('jocker-comic-ai-artwork-901.webp', 1)
img3 = cv2.imread('jocker-comic-ai-artwork-901.webp', 1)
img[20, 40] = 255 # img[y,x]
img2[0:20,0:40] = 255

 

roi = img[50:100, 100:150]
img3[0:50, 0:50] = roi 
cv2.imshow('Car', img)
cv2.imshow('Car2', img2)
cv2.imshow('Car3', img3)
cv2.waitKey(0)
cv2.destroyAllWindows()

 

#============plot===========
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
plt.subplot(131),plt.imshow(img),plt.title('pixels')
plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(img2),plt.title('area')
plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(img3),plt.title('roi')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv2.imread('jocker-comic-ai-artwork-901.webp', 1)
b,g,r=cv2.split(img)
img=cv2.merge((r,g,b))
img=cv2.merge((g,r,b))

plt.subplot(131),plt.imshow(img),plt.title('bgr')
plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(img2),plt.title('rgb')
plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(img3),plt.title('grb')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv2.imread('jocker-comic-ai-artwork-901.webp',1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(1,2,1),plt.imshow(img)
plt.title('image'), plt.xticks([]), plt.yticks([])

 

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray, 10, 255, 0)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
img2 = cv2.drawContours(img, contours, -1, (0,255,0), 2)

 

print(len(contours))

 

cv2.imshow('CAR',img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

 

plt.subplot(1,2,2),plt.imshow(img2,cmap='gray')
plt.title('image2'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# 521

# %%
import numpy as np
import cv2 as cv

 

events = [i for i in dir(cv) if 'RETR' in i]
print(events)
# Out:
# ['RETR_CCOMP', 'RETR_EXTERNAL', 'RETR_FLOODFILL', 'RETR_LIST', 'RETR_TREE']

# %%
img = cv2.imread('jocker-comic-ai-artwork-901.webp',1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(1,2,1),plt.imshow(img)
plt.title('image'), plt.xticks([]), plt.yticks([])

 

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray, 10, 255, 0)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)
img2 = cv2.drawContours(img, contours, -1, (0,255,0), 2)

 

print(len(contours))

 

cv2.imshow('CAR',img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

 

plt.subplot(1,2,2),plt.imshow(img2,cmap='gray')
plt.title('image2'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# 521

# %%
img = cv2.imread('jocker-comic-ai-artwork-901.webp',1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(1,2,1),plt.imshow(img)
plt.title('image'), plt.xticks([]), plt.yticks([])

 

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray, 10, 255, 0)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
img2 = cv2.drawContours(img, contours, -1, (255,0,0), 2)

 

print(len(contours))

 

cv2.imshow('CAR',img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

 

plt.subplot(1,2,2),plt.imshow(img2,cmap='gray')
plt.title('image2'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# 7

# %%
img = cv2.imread('jocker-comic-ai-artwork-901.webp',1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(1,2,1),plt.imshow(img)
plt.title('image'), plt.xticks([]), plt.yticks([])

 

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray, 10, 255, 0)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
img2 = cv2.drawContours(img, contours, -1, (0,255,0), 2)

 

print(len(contours))

 

cv2.imshow('CAR',img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

 

plt.subplot(1,2,2),plt.imshow(img2,cmap='gray')
plt.title('image2'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# 521

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

cap = cv.VideoCapture(0)

while True:
    ret, frame = cap.read()

    # Check if the frame is empty or has invalid dimensions
    if not ret or frame.size == 0:
        continue
    frame=cv.circle(frame, (frame.shape[1]//2, frame.shape[0]//2), 100, (0,0,255), thickness=3)    
    frame=cv.line( frame, ((frame.shape[1]//2)-100,0), ((frame.shape[1]//2)-100,600), (255,0,255), thickness=5)
    frame=cv.line( frame, (0,(frame.shape[1]//2)-300), (1800,(frame.shape[1]//2)-300), (255,0,255), thickness=5)
    frame=cv.line( frame, ((frame.shape[1]//2)+100,0), ((frame.shape[1]//2)+100,600), (255,0,255), thickness=5)
    frame=cv.line( frame, (0,(frame.shape[1]//2)+100), (1800,(frame.shape[1]//2)+100), (255,0,255), thickness=5)
    cv.imshow('Video', frame)

    if cv.waitKey(1) == ord('q'):
        break

cap.release()
cv.destroyAllWindows()
plt.imshow(frame)

# %%
video = cv.VideoCapture(0)
while(True):
    boolean, frame = video.read()
    cv2.imshow("video", frame)
    key = cv2.waitKey(1)
    if key == ord('q'):
        frame_final = frame
        break
video.release()
cv2.destroyAllWindows()

 

#============plot===========
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.imshow(frame)

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

cap = cv.VideoCapture(0)

while True:
    ret, frame = cap.read()

    # Check if the frame is empty or has invalid dimensions
    if not ret or frame.size == 0:
        continue
    frame=cv.circle(frame, (frame.shape[1]//2, frame.shape[0]//2), 100, (0,0,255), thickness=3)    
    frame=cv.line( frame, ((frame.shape[1]//2)-100,0), ((frame.shape[1]//2)-100,600), (255,0,255), thickness=5)
    frame=cv.line( frame, (0,(frame.shape[1]//2)-300), (1800,(frame.shape[1]//2)-300), (255,0,255), thickness=5)
    frame=cv.line( frame, ((frame.shape[1]//2)+100,0), ((frame.shape[1]//2)+100,600), (255,0,255), thickness=5)
    frame=cv.line( frame, (0,(frame.shape[1]//2)+100), (1800,(frame.shape[1]//2)+100), (255,0,255), thickness=5)
    cv.imshow('Video', frame)

    if cv.waitKey(1) == ord('q'):
        break

cap.release()
cv.destroyAllWindows()
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.imshow(frame)

# %%
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
print(frame.shape)
print(frame.size)
print(frame.dtype)
b,g,r=cv2.split(frame)
img=cv2.merge((r,g,b))
img2=cv2.merge((g,r,b))
plt.imshow(img)
plt.imshow(img2)
# Out:
# (480, 640, 3)
# 921600
# uint8

# %%
def click_event(event,x,y,flags,param):
    if event == cv.EVENT_LBUTTONDOWN:
        print(x,', ',y)
        font = cv.FONT_HERSHEY_SIMPLEX
        strxy = str(x) + ', '+ str(y)
        cv.putText(img,strxy,(x,y),font,1,(255,255,0),2)
        cv.imshow('image',img)
img = cv2.imread('jocker-comic-ai-artwork-901.webp',1)
cv.imshow('image',img)

 

cv.setMouseCallback('image',click_event)

 

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 312 ,  181
# 818 ,  199

# %%
import numpy as np
import cv2

 

img1 = cv2.imread('jocker-comic-ai-artwork-901.webp')
img2 = cv2.imread('download.jpg')


img1 = cv2.resize(img1, (125, 175))
img2 = cv2.resize(img2, (125, 175))

 

dst = cv2.add(img1, img2)

 

cv2.imshow('image',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()
plt.imshow(dst)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the two images
image1 = cv2.imread('jocker-comic-ai-artwork-901.webp')
image2 = cv2.imread('download.jpg')

# Resize the second image to match the size of the first image
image2 = cv2.resize(image2, (image1.shape[1], image1.shape[0]))

# Specify the weights for each image
alpha = 0.5  # Weight for the first image
beta = 0.5   # Weight for the second image
gamma = 0    # Scalar added to the blended images

# Combine the images
blended_image = cv2.addWeighted(image1, alpha, image2, beta, gamma)

# Display the result
cv2.imshow('Blended Image', blended_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
plt.imshow(blended_image)

# %%
#confusion matrix

#Import the necessary libraries

import numpy as np

from sklearn.metrics import confusion_matrix

import seaborn as sns

import matplotlib.pyplot as plt

 

#Create the NumPy array for actual and predicted labels.

actual = np.array(

['Dog','Dog','Dog','Not Dog','Dog','Not Dog','Dog','Dog','Not Dog','Not Dog'])

predicted = np.array(

['Dog','Not Dog','Dog','Not Dog','Dog','Dog','Dog','Dog','Not Dog','Not Dog'])

 

#compute the confusion matrix.

cm = confusion_matrix(actual,predicted)

 

#Plot the confusion matrix.

sns.heatmap(cm,annot=True,fmt='g',xticklabels=['Dog','Not Dog'],yticklabels=['Dog','Not Dog'])

plt.ylabel('Prediction',fontsize=13)

plt.xlabel('Actual',fontsize=13)

plt.title('Confusion Matrix',fontsize=17)

plt.show()

# %%
#Import the necessary libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

 

# Load the breast cancer dataset
X, y= load_breast_cancer(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25)

 

# Train the model
tree = DecisionTreeClassifier(random_state=23)
tree.fit(X_train, y_train)

 

# preduction
y_pred = tree.predict(X_test)

 

# compute the confusion matrix
cm = confusion_matrix(y_test,y_pred)

 

#Plot the confusion matrix.
sns.heatmap(cm,
            annot=True,
            fmt='g',
            xticklabels=['malignant', 'benign'],
            yticklabels=['malignant', 'benign'])
plt.ylabel('Prediction',fontsize=13)
plt.xlabel('Actual',fontsize=13)
plt.title('Confusion Matrix',fontsize=17)
plt.show()

 


# Finding precision and recall
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy :", accuracy)
precision = precision_score(y_test, y_pred)
print("Precision :", precision)
recall = recall_score(y_test, y_pred)
print("Recall :", recall)
F1_score = f1_score(y_test, y_pred)
print("F1-score :", F1_score)
# Out:
# Accuracy : 0.9440559440559441
# Precision : 0.94
# Recall : 0.9791666666666666
# F1-score : 0.9591836734693877
